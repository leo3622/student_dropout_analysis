# %% [markdown]
# # Data Processing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


from scripts.graph import plot_graph, save_graph

# Load the dataset
df = pd.read_csv('data/student_data.csv', encoding='utf-8', sep=';')
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    evening attendance  Previous qualification  Nacionality  \
# 0                   1                       1            1
# 1                   1                       1            1
# 2                   1                       1            1
# 3                   1                       1            1
# 4                   0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %%
# Display basic information about the dataset
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   evening attendance                              4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nacionality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
# ...

# %%
# Check for missing values
missing_values = df.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# evening attendance                                0
# Previous qualification                            0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# ...

# %%
# View column names
print("Column names in the dataset:")
print(df.columns.tolist())
# Out:
# Column names in the dataset:
# ['Marital status', 'Application mode', 'Application order', 'Course', 'evening attendance', 'Previous qualification', 'Nacionality', "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", 'Displaced', 'Educational special needs', 'Debtor', 'Tuition fees up to date', 'Gender', 'Scholarship holder', 'Age at enrollment', 'International', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (enrolled)', 'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (approved)', 'Curricular units 1st sem (grade)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (enrolled)', 'Curricular units 2nd sem (evaluations)', 'Curricular units 2nd sem (approved)', 'Curricular units 2nd sem (grade)', 'Curricular units 2nd sem (without evaluations)', 'Unemployment rate', 'Inflation rate', 'GDP', 'Output']

# %%
# How student performance affects their dropout rate
df['performance_score'] = (df['Curricular units 1st sem (grade)'] + df['Curricular units 2nd sem (grade)']) / 2

# Calculate average performance score by output group
avg_score_each_group = df.groupby('Output')['performance_score'].mean()

avg_score_each_group = avg_score_each_group.reset_index()
avg_score_each_group.columns = ['Output Group', 'Average Performance Score']


graph = plot_graph(avg_score_each_group, 'Output Group', 'Average Performance Score', 'Average Performance Score by Output Group', 'Output Group', 'Average Performance Score', ['skyblue', 'orange', 'green'], 'bar', legend=False)
save_graph(graph, '../pictures/avg_performance_score_by_output.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 12
#       8 avg_score_each_group.columns = ['Output Group', 'Average Performance Score']
#      11 graph = plot_graph(avg_score_each_group, 'Output Group', 'Average Performance Score', 'Average Performance Score by Output Group', 'Output Group', 'Average Performance Score', ['skyblue', 'orange', 'green'], 'bar', legend=False)
# ---> 12 save_graph(graph, '../pictures/avg_performance_score_by_output.png')
#
# File /mnt/c/Users/dho39/Desktop/LeoPersonalProjects/student_data_analysis/scripts/graph.py:38, in save_graph(graph, filename)
#      30 def save_graph(graph, filename):
#      31     """
#      32     Saves the plotted graph to a file.
#      33
#    (...)
#      36     - filename: Name of the file to save the graph as.
#      37     """
# ---> 38     graph.savefig(filename)
#
# ...

# %%
# How evening classes affect student output
num_to_category = {1: 'Day time', 0: 'Evening time'}
df['evening attendance'] = df['evening attendance'].map(num_to_category)

# %%
# Count the number of students in each output group for evening and day time classes
output_counts = pd.crosstab(df['evening attendance'], df['Output'])
output_counts = output_counts.reset_index()
graph = plot_graph(output_counts, 'evening attendance', ['Dropout', 'Enrolled', 'Graduate'], 'Student Output by Class Time',
                   'Class Time', 'Number of Students', ['skyblue', 'orange', 'green'], 'bar', legend=True, stacked=True)
save_graph(graph, '../pictures/student_output_by_class_time.png')

# %%
# Gender and output group analysis
gender_decoder = {1: 'Male', 0: 'Female'}
df['Gender'] = df['Gender'].map(gender_decoder)

# %%
gender_output_counts = pd.crosstab(df['Gender'], df['Output'])
avg_dropout_by_gender = (
    gender_output_counts['Dropout'] /
    gender_output_counts.sum(axis=1) * 100
)
avg_dropout_by_gender.plot(kind='bar', color=['skyblue', 'orange'])
plt.title('Average Dropout Rate by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Dropout Rate (%)')
plt.xticks(rotation=0)
plt.savefig('../pictures/avg_dropout_by_gender.png')
plt.show()

# %%
# Nationality distribution
nationality_decoder = {
    1: "Portuguese",
    2: "German",
    6: "Spanish",
    11: "Italian",
    13: "Dutch",
    14: "English",
    17: "Lithuanian",
    21: "Angolan",
    22: "Cape Verdean",
    24: "Guinean",
    25: "Mozambican",
    26: "Santomean",
    32: "Turkish",
    41: "Brazilian",
    62: "Romanian",
    100: "Moldova (Republic of)",
    101: "Mexican",
    103: "Ukrainian",
    105: "Russian",
    108: "Cuban",
    109: "Colombian"
}

df.rename(columns={'Nacionality': 'Nationality'}, inplace=True)
df['Nationality'] = df['Nationality'].map(nationality_decoder)

# %%
nationality_count = df['Nationality'].value_counts().reset_index()
nationality_count.columns = ['nationality', 'count']
nationality_count
# Out:
#   nationality  count
# 0  Portuguese   4314
# 1     English     38
# 2     Italian      2
# 3  Lithuanian      2
# 4      German      2
# 5       Dutch      1
# 6     Angolan      1
# 7     Spanish      1

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='count', y='nationality', data=nationality_count, palette='pastel')
plt.xscale('log')
plt.title('Student Distribution by Nationality')
plt.xlabel('Number of Students')
plt.ylabel('Nationality')
plt.savefig('../pictures/student_distribution_by_nationality.png')
plt.show()
# Out:
# /tmp/ipykernel_7719/2258526399.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='count', y='nationality', data=nationality_count, palette='pastel')

# %% [markdown]
# ## Modeling, validation, and fairness
#
# A quick summary of the production-style pipeline added for the resume version of this project:
# - Clean + normalize categorical codes, add `performance_score`, and clip numeric outliers.
# - Stratified train/test split (20%) with pipelines for imputation, one-hot encoding, and scaling.
# - Benchmarked baseline dummy vs logistic regression vs tuned random forest; reports saved to `../reports/model_report.json`.
# - Fairness audit for dropout detection by gender and class time (precision/recall).

# %%
import json
from pathlib import Path

report_path = Path('../reports/model_report.json')
if report_path.exists():
    with report_path.open() as f:
        report = json.load(f)
    best = report.get('best_model')
    report
else:
    print('Run `make train` to generate reports/model_report.json')

# %%
# Display fairness audit for the best model if available
import json
import pandas as pd
from pathlib import Path

report_path = Path('../reports/model_report.json')
if report_path.exists():
    with report_path.open() as f:
        report = json.load(f)
    best = report.get('best_model')
    fairness = report['models'][best].get('fairness', {})
    for group, scores in fairness.items():
        display(pd.DataFrame(scores).T)
else:
    print('No fairness report yet; run training first.')
